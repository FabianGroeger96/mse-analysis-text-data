# %% [markdown]
# # AnTeDe Lab A: Understanding PoS tags
#
# ## Session goal
# The goal of this session is to help you familiarize with PoS tags. We begin by importing the NLTK fragments of the Brown corpus and the Wall Street Journal.

# %%
import nltk
nltk.download('brown')
nltk.download('treebank')
nltk.download('universal_tagset')
from nltk.corpus import brown 
from nltk.corpus import treebank
# Out:
# [nltk_data] Downloading package brown to /Users/Daniele/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package treebank to
# [nltk_data]     /Users/Daniele/nltk_data...
# [nltk_data]   Package treebank is already up-to-date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     /Users/Daniele/nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!

# %% [markdown]
# Complete the inner loop of the following function as directed by the comments.

# %%
def get_ground_truth_distribution(token, corpus, universal_tagset=False):
    
    if universal_tagset:
        corpus_tagset='universal'
    else:
        corpus_tagset=''
        
    sentences = corpus.tagged_sents(tagset=corpus_tagset)
    untagged_sentences = corpus.sents()
    
    # this is going to be a dict where each key is a tag
    tag_freq={}
    
    # sent is an untagged sentence
    # sentences[i] is the corresponding tagged sentence
    
    for i, sent in enumerate(untagged_sentences):
            # if the token we're looking for is in sent
            if token in sent:
                # for each (token, tag) tuple in the tagged sentence
                for pair in sentences[i]:
                    
                    # pair[0] contains the current token
                    # pair[1] contains the corresponding tag
                    
                    # increase tag_freq[pair[1]] by one unit
                    # careful because tag_freq may not yet have a 
                    # key corresponding to pair[1]!
                    
# BEGIN_REMOVE                    
                    if pair[0] == token:
                        try:
                            tag_freq[pair[1]]+=1
                        except:
                            tag_freq[pair[1]]=1
# END_REMOVE                            
    return tag_freq

# %% [markdown]
# In the following cells, we get the PoS tag distribution of *that* in the Penn treebank and the Brown corpus using the universal and the Penn tagset (for Penn) and the Brown tagset (for Brown).

# %%
get_ground_truth_distribution(token='fast', corpus=treebank)
# Out:
# {'RB': 2, 'JJ': 1}

# %% [markdown]
# The following function gives you examples for a specific combination of token and tag.

# %%
def get_ground_truth_examples(token, corpus, tag, universal_tagset=False):
    
    if universal_tagset:
        corpus_tagset='universal'
    else:
        corpus_tagset=''
    
    sentences =corpus.tagged_sents(tagset=corpus_tagset)
    untagged_sentences = corpus.sents()
    tag_freq={}
    count=0
    visualize=False
    
    
    for i, sent in enumerate(untagged_sentences):
        
        if token in sent:
            text=""
            for pair in sentences[i]:
                if 'NONE' not in pair[1]:
                    text = text+" "+pair[0]
                if (pair[0]==token) and (pair[1]==tag):
                    visualize=True    
            if visualize:
                count=count+1
                print (str(count)+' '+text)
                print (str(sentences[i]))
                visualize=False

# %%
get_ground_truth_examples(token='fast', corpus=treebank, tag='JJ')
# Out:
# 1  The New York Stock Exchange 's attempt to introduce a new portfolio basket is evidence of investors ' desires to make fast and easy transactions of large numbers of shares .
# [('The', 'DT'), ('New', 'NNP'), ('York', 'NNP'), ('Stock', 'NNP'), ('Exchange', 'NNP'), ("'s", 'POS'), ('attempt', 'NN'), ('*', '-NONE-'), ('to', 'TO'), ('introduce', 'VB'), ('a', 'DT'), ('new', 'JJ'), ('portfolio', 'NN'), ('basket', 'NN'), ('is', 'VBZ'), ('evidence', 'NN'), ('of', 'IN'), ('investors', 'NNS'), ("'", 'POS'), ('desires', 'NNS'), ('*', '-NONE-'), ('to', 'TO'), ('make', 'VB'), ('fast', 'JJ'), ('and', 'CC'), ('easy', 'JJ'), ('transactions', 'NNS'), ('of', 'IN'), ('large', 'JJ'), ('numbers', 'NNS'), ('of', 'IN'), ('shares', 'NNS'), ('.', '.')]

# %%
get_ground_truth_distribution(token='that', corpus=treebank)
# Out:
# {'WDT': 214, 'IN': 513, 'DT': 77, 'RB': 3}

# %%
get_ground_truth_examples(token='that', corpus=treebank, tag='IN')
# Out:
# 1  The finding probably will support those who argue that the U.S. should regulate the class of asbestos including crocidolite more stringently than the common kind of asbestos , chrysotile , found in most schools and other buildings , Dr. Talcott said .
# [('The', 'DT'), ('finding', 'NN'), ('probably', 'RB'), ('will', 'MD'), ('support', 'VB'), ('those', 'DT'), ('who', 'WP'), ('*T*-6', '-NONE-'), ('argue', 'VBP'), ('that', 'IN'), ('the', 'DT'), ('U.S.', 'NNP'), ('should', 'MD'), ('regulate', 'VB'), ('the', 'DT'), ('class', 'NN'), ('of', 'IN'), ('asbestos', 'NN'), ('including', 'VBG'), ('crocidolite', 'NN'), ('more', 'RBR'), ('stringently', 'RB'), ('than', 'IN'), ('the', 'DT'), ('common', 'JJ'), ('kind', 'NN'), ('of', 'IN'), ('asbestos', 'NN'), (',', ','), ('chrysotile', 'NN'), (',', ','), ('found', 'VBN'), ('*', '-NONE-'), ('in', 'IN'), ('most', 'JJS'), ('schools', 'NNS'), ('and', 'CC'), ('other', 'JJ'), ('buildings', 'NNS'), (',', ','), ('Dr.', 'NNP'), ('Talcott', 'NNP'), ('said', 'VBD'), ('0', '-NONE-'), ('*T*-1', '-NONE-'), ('.', '.')]
# 2  `` There 's no question that some of those workers and managers contracted asbestos-related diseases , '' said Darrell Phillips , vice president of human resources for Hollingsworth & Vose .
# [('``', '``'), ('There', 'EX'), ("'s", 'VBZ'), ('no', 'DT'), ('question', 'NN'), ('that', 'IN'), ('some', 'DT'), ('of', 'IN'), ('those', 'DT'), ('workers', 'NNS'), ('and', 'CC'), ('managers', 'NNS'), ('contracted', 'VBD'), ('asbestos-related', 'JJ'), ('diseases', 'NNS'), (',', ','), ("''", "''"), ('said', 'VBD'), ('*T*-1', '-NONE-'), ('Darrell', 'NNP'), ('Phillips', 'NNP'), (',', ','), ('vice', 'NN'), ('president', 'NN'), ('of', 'IN'), ('human', 'JJ'), ('resources', 'NNS'), ('for', 'IN'), ('Hollingsworth', 'NNP'), ('&', 'CC'), ('Vose', 'NNP'), ('.', '.')]
# 3  `` But you have to recognize that these events took place 35 years ago .
# [('``', '``'), ('But', 'CC'), ('you', 'PRP'), ('have', 'VBP'), ('*-1', '-NONE-'), ('to', 'TO'), ('recognize', 'VB'), ('that', 'IN'), ('these', 'DT'), ('events', 'NNS'), ('took', 'VBD'), ('place', 'NN'), ('35', 'CD'), ('years', 'NNS'), ('ago', 'IN'), ('.', '.')]
# 4  Yields on money-market mutual funds continued to slide , amid signs that portfolio managers expect further declines in interest rates .
# [('Yields', 'NNS'), ('on', 'IN'), ('money-market', 'JJ'), ('mutual', 'JJ'), ('funds', 'NNS'), ('continued', 'VBD'), ('*-1', '-NONE-'), ('to', 'TO'), ('slide', 'VB'), (',', ','), ('amid', 'IN'), ('signs', 'NNS'), ('that', 'IN'), ('portfolio', 'NN'), ('managers', 'NNS'), ('expect', 'VBP'), ('further', 'JJ'), ('declines', 'NNS'), ('in', 'IN'), ('interest', 'NN'), ('rates', 'NNS'), ('.', '.')]
# 5  Compound yields assume reinvestment of dividends and that the current yield continues for a year .
# [('Compound', 'NN'), ('yields', 'NNS'), ('assume', 'VBP'), ('reinvestment', 'NN'), ('of', 'IN'), ('dividends', 'NNS'), ('and', 'CC'), ('that', 'IN'), ('the', 'DT'), ('current', 'JJ'), ('yield', 'NN'), ('continues', 'VBZ'), ('for', 'IN'), ('a', 'DT'), ('year', 'NN'), ('.', '.')]
# 6  The idea , of course : to prove to 125 corporate decision makers that the buckle on the Rust Belt is n't so rusty after all , that it 's a good place for a company to expand .
# [('The', 'DT'), ('idea', 'NN'), (',', ','), ('of', 'IN'), ('course', 'NN'), (':', ':'), ('*', '-NONE-'), ('to', 'TO'), ('prove', 'VB'), ('to', 'TO'), ('125', 'CD'), ('corporate', 'JJ'), ('decision', 'NN'), ('makers', 'NNS'), ('that', 'IN'), ('the', 'DT'), ('buckle', 'NN'), ('on', 'IN'), ('the', 'DT'), ('Rust', 'NNP'), ('Belt', 'NNP'), ('is', 'VBZ'), ("n't", 'RB'), ('so', 'RB'), ('rusty', 'JJ'), ('after', 'IN'), ('all', 'DT'), (',', ','), ('that', 'IN'), ('it', 'PRP'), ("'s", 'VBZ'), ('a', 'DT'), ('good', 'JJ'), ('place', 'NN'), ('0', '-NONE-'), ('for', 'IN'), ('a', 'DT'), ('company', 'NN'), ('to', 'TO'), ('expand', 'VB'), ('*T*-1', '-NONE-'), ('.', '.')]
# 7  New England Electric System bowed out of the bidding for Public Service Co. of New Hampshire , saying that the risks were too high and the potential payoff too far in the future to justify a higher offer .
# [('New', 'NNP'), ('England', 'NNP'), ('Electric', 'NNP'), ('System', 'NNP'), ('bowed', 'VBD'), ('out', 'IN'), ('of', 'IN'), ('the', 'DT'), ('bidding', 'NN'), ('for', 'IN'), ('Public', 'NNP'), ('Service', 'NNP'), ('Co.', 'NNP'), ('of', 'IN'), ('New', 'NNP'), ('Hampshire', 'NNP'), (',', ','), ('*-1', '-NONE-'), ('saying', 'VBG'), ('that', 'IN'), ('the', 'DT'), ('risks', 'NNS'), ('were', 'VBD'), ('too', 'RB'), ('high', 'JJ'), ('*RNR*-4', '-NONE-'), ('and', 'CC'), ('the', 'DT'), ('potential', 'JJ'), ('payoff', 'NN'), ('too', 'RB'), ('far', 'RB'), ('in', 'IN'), ('the', 'DT'), ('future', 'NN'), ('*RNR*-4', '-NONE-'), ('*', '-NONE-'), ('to', 'TO'), ('justify', 'VB'), ('a', 'DT'), ('higher', 'JJR'), ('offer', 'NN'), ('.', '.')]
# 8  Mr. Rowe also noted that political concerns also worried New England Electric .
# [('Mr.', 'NNP'), ('Rowe', 'NNP'), ('also', 'RB'), ('noted', 'VBD'), ('that', 'IN'), ('political', 'JJ'), ('concerns', 'NNS'), ('also', 'RB'), ('worried', 'VBN'), ('New', 'NNP'), ('England', 'NNP'), ('Electric', 'NNP'), ('.', '.')]
# 9  The fact that New England proposed lower rate increases -- 4.8 % over seven years against around 5.5 % boosts proposed by the other two outside bidders -- complicated negotiations with state officials , Mr. Ross asserted .
# [('The', 'DT'), ('fact', 'NN'), ('that', 'IN'), ('New', 'NNP'), ('England', 'NNP'), ('proposed', 'VBD'), ('lower', 'JJR'), ('rate', 'NN'), ('increases', 'NNS'), ('--', ':'), ('4.8', 'CD'), ('%', 'NN'), ('*U*', '-NONE-'), ('over', 'IN'), ('seven', 'CD'), ('years', 'NNS'), ('against', 'IN'), ('around', 'IN'), ('5.5', 'CD'), ('%', 'NN'), ('boosts', 'NNS'), ('proposed', 'VBN'), ('*', '-NONE-'), ('by', 'IN'), ('the', 'DT'), ('other', 'JJ'), ('two', 'CD'), ('outside', 'JJ'), ('bidders', 'NNS'), ('--', ':'), ('complicated', 'IN'), ('negotiations', 'NNS'), ('with', 'IN'), ('state', 'NN'), ('officials', 'NNS'), (',', ','), ('Mr.', 'NNP'), ('Ross', 'NNP'), ('asserted', 'VBD'), ('0', '-NONE-'), ('*T*-1', '-NONE-'), ('.', '.')]
# 10  Northeast said it would refile its request and still hopes for an expedited review by the FERC so that it could complete the purchase by next summer if its bid is the one approved by the bankruptcy court .
# [('Northeast', 'NNP'), ('said', 'VBD'), ('0', '-NONE-'), ('it', 'PRP'), ('would', 'MD'), ('refile', 'VB'), ('its', 'PRP$'), ('request', 'NN'), ('and', 'CC'), ('still', 'RB'), ('hopes', 'VBZ'), ('for', 'IN'), ('an', 'DT'), ('expedited', 'VBN'), ('review', 'NN'), ('by', 'IN'), ('the', 'DT'), ('FERC', 'NNP'), ('so', 'IN'), ('that', 'IN'), ('it', 'PRP'), ('could', 'MD'), ('complete', 'VB'), ('the', 'DT'), ('purchase', 'NN'), ('by', 'IN'), ('next', 'JJ'), ('summer', 'NN'), ('if', 'IN'), ('its', 'PRP$'), ('bid', 'NN'), ('is', 'VBZ'), ('the', 'DT'), ('one', 'NN'), ('approved', 'VBD'), ('*', '-NONE-'), ('by', 'IN'), ('the', 'DT'), ('bankruptcy', 'NN'), ('court', 'NN'), ('.', '.')]
# 11  Judge Curry ordered the refunds to begin Feb. 1 and said that he would n't entertain any appeals or other attempts to block his order by Commonwealth Edison .
# [('Judge', 'NNP'), ('Curry', 'NNP'), ('ordered', 'VBD'), ('the', 'DT'), ('refunds', 'NNS'), ('*-1', '-NONE-'), ('to', 'TO'), ('begin', 'VB'), ('Feb.', 'NNP'), ('1', 'CD'), ('and', 'CC'), ('said', 'VBD'), ('that', 'IN'), ('he', 'PRP'), ('would', 'MD'), ("n't", 'RB'), ('entertain', 'VB'), ('any', 'DT'), ('appeals', 'NNS'), ('or', 'CC'), ('other', 'JJ'), ('attempts', 'NNS'), ('*', '-NONE-'), ('to', 'TO'), ('block', 'VB'), ('his', 'PRP$'), ('order', 'NN'), ('by', 'IN'), ('Commonwealth', 'NNP'), ('Edison', 'NNP'), ('.', '.')]
# 12  A Commonwealth Edison spokesman said that tracking down the two million customers whose addresses have changed during the past 3 1\/2 years would be `` an administrative nightmare . ''
# [('A', 'DT'), ('Commonwealth', 'NNP'), ('Edison', 'NNP'), ('spokesman', 'NN'), ('said', 'VBD'), ('that', 'IN'), ('*', '-NONE-'), ('tracking', 'VBG'), ('down', 'RP'), ('the', 'DT'), ('two', 'CD'), ('million', 'CD'), ('customers', 'NNS'), ('whose', 'WP$'), ('addresses', 'NNS'), ('*T*-20', '-NONE-'), ('have', 'VBP'), ('changed', 'VBN'), ('during', 'IN'), ('the', 'DT'), ('past', 'JJ'), ('3', 'CD'), ('1\\/2', 'CD'), ('years', 'NNS'), ('would', 'MD'), ('be', 'VB'), ('``', '``'), ('an', 'DT'), ('administrative', 'JJ'), ('nightmare', 'NN'), ('.', '.'), ("''", "''")]
# 13  In August , the commission ruled that between $ 190 million and $ 195 million of the plant 's construction cost was unreasonable and should be refunded , plus interest .
# [('In', 'IN'), ('August', 'NNP'), (',', ','), ('the', 'DT'), ('commission', 'NN'), ('ruled', 'VBD'), ('that', 'IN'), ('between', 'IN'), ('$', '$'), ('190', 'CD'), ('million', 'CD'), ('and', 'CC'), ('$', '$'), ('195', 'CD'), ('million', 'CD'), ('*U*', '-NONE-'), ('of', 'IN'), ('the', 'DT'), ('plant', 'NN'), ("'s", 'POS'), ('construction', 'NN'), ('cost', 'NN'), ('was', 'VBD'), ('unreasonable', 'JJ'), ('and', 'CC'), ('should', 'MD'), ('be', 'VB'), ('refunded', 'VBN'), ('*-1', '-NONE-'), (',', ','), ('plus', 'CC'), ('interest', 'NN'), ('.', '.')]
# 14  Commonwealth Edison now faces an additional court-ordered refund on its summer\/winter rate differential collections that the Illinois Appellate Court has estimated at $ 140 million .
# [('Commonwealth', 'NNP'), ('Edison', 'NNP'), ('now', 'RB'), ('faces', 'VBZ'), ('an', 'DT'), ('additional', 'JJ'), ('court-ordered', 'JJ'), ('refund', 'NN'), ('on', 'IN'), ('its', 'PRP$'), ('summer\\/winter', 'JJ'), ('rate', 'NN'), ('differential', 'JJ'), ('collections', 'NNS'), ('that', 'IN'), ('the', 'DT'), ('Illinois', 'NNP'), ('Appellate', 'NNP'), ('Court', 'NNP'), ('has', 'VBZ'), ('estimated', 'VBN'), ('*T*-1', '-NONE-'), ('at', 'IN'), ('$', '$'), ('140', 'CD'), ('million', 'CD'), ('*U*', '-NONE-'), ('.', '.')]
# 15  And consumer groups hope that Judge Curry 's Byron 1 order may set a precedent for a second nuclear rate case involving Commonwealth Edison 's Braidwood 2 plant .
# [('And', 'CC'), ('consumer', 'NN'), ('groups', 'NNS'), ('hope', 'VBP'), ('that', 'IN'), ('Judge', 'NNP'), ('Curry', 'NNP'), ("'s", 'POS'), ('Byron', 'NNP'), ('1', 'CD'), ('order', 'NN'), ('may', 'MD'), ('set', 'VB'), ('a', 'DT'), ('precedent', 'NN'), ('for', 'IN'), ('a', 'DT'), ('second', 'JJ'), ('nuclear', 'JJ'), ('rate', 'NN'), ('case', 'NN'), ('involving', 'VBG'), ('Commonwealth', 'NNP'), ('Edison', 'NNP'), ("'s", 'POS'), ('Braidwood', 'NNP'), ('2', 'CD'), ('plant', 'NN'), ('.', '.')]
# 16  Documents filed with the Securities and Exchange Commission on the pending spinoff disclosed that Cray Research Inc. will withdraw the almost $ 100 million in financing it is providing the new firm if Mr. Cray leaves or if the product-design project he heads is scrapped .
# [('Documents', 'NNS'), ('filed', 'VBN'), ('*', '-NONE-'), ('with', 'IN'), ('the', 'DT'), ('Securities', 'NNPS'), ('and', 'CC'), ('Exchange', 'NNP'), ('Commission', 'NNP'), ('on', 'IN'), ('the', 'DT'), ('pending', 'VBG'), ('spinoff', 'NN'), ('disclosed', 'VBD'), ('that', 'IN'), ('Cray', 'NNP'), ('Research', 'NNP'), ('Inc.', 'NNP'), ('will', 'MD'), ('withdraw', 'VB'), ('the', 'DT'), ('almost', 'RB'), ('$', '$'), ('100', 'CD'), ('million', 'CD'), ('*U*', '-NONE-'), ('in', 'IN'), ('financing', 'NN'), ('0', '-NONE-'), ('it', 'PRP'), ('is', 'VBZ'), ('providing', 'VBG'), ('the', 'DT'), ('new', 'JJ'), ('firm', 'NN'), ('*T*-1', '-NONE-'), ('if', 'IN'), ('Mr.', 'NNP'), ('Cray', 'NNP'), ('leaves', 'VBZ'), ('or', 'CC'), ('if', 'IN'), ('the', 'DT'), ('product-design', 'JJ'), ('project', 'NN'), ('0', '-NONE-'), ('he', 'PRP'), ('heads', 'VBZ'), ('*T*-2', '-NONE-'), ('is', 'VBZ'), ('scrapped', 'VBN'), ('*-18', '-NONE-'), ('.', '.')]
# 17  The documents also said that although the 64-year-old Mr. Cray has been working on the project for more than six years , the Cray-3 machine is at least another year away from a fully operational prototype .
# [('The', 'DT'), ('documents', 'NNS'), ('also', 'RB'), ('said', 'VBD'), ('that', 'IN'), ('although', 'IN'), ('the', 'DT'), ('64-year-old', 'JJ'), ('Mr.', 'NNP'), ('Cray', 'NNP'), ('has', 'VBZ'), ('been', 'VBN'), ('working', 'VBG'), ('on', 'IN'), ('the', 'DT'), ('project', 'NN'), ('for', 'IN'), ('more', 'RBR'), ('than', 'IN'), ('six', 'CD'), ('years', 'NNS'), (',', ','), ('the', 'DT'), ('Cray-3', 'NNP'), ('machine', 'NN'), ('is', 'VBZ'), ('at', 'IN'), ('least', 'JJS'), ('another', 'DT'), ('year', 'NN'), ('away', 'RB'), ('from', 'IN'), ('a', 'DT'), ('fully', 'RB'), ('operational', 'JJ'), ('prototype', 'NN'), ('.', '.')]
# 18  `` The theory is that Seymour is the chief designer of the Cray-3 , and without him it could not be completed .
# [('``', '``'), ('The', 'DT'), ('theory', 'NN'), ('is', 'VBZ'), ('that', 'IN'), ('Seymour', 'NNP'), ('is', 'VBZ'), ('the', 'DT'), ('chief', 'JJ'), ('designer', 'NN'), ('of', 'IN'), ('the', 'DT'), ('Cray-3', 'NNP'), (',', ','), ('and', 'CC'), ('without', 'IN'), ('him', 'PRP'), ('it', 'PRP'), ('could', 'MD'), ('not', 'RB'), ('be', 'VB'), ('completed', 'VBN'), ('*-20', '-NONE-'), ('.', '.')]
# 19  The documents also said that Cray Computer anticipates needing perhaps another $ 120 million in financing beginning next September .
# [('The', 'DT'), ('documents', 'NNS'), ('also', 'RB'), ('said', 'VBD'), ('that', 'IN'), ('Cray', 'NNP'), ('Computer', 'NNP'), ('anticipates', 'VBZ'), ('*-1', '-NONE-'), ('needing', 'VBG'), ('perhaps', 'RB'), ('another', 'DT'), ('$', '$'), ('120', 'CD'), ('million', 'CD'), ('*U*', '-NONE-'), ('in', 'IN'), ('financing', 'NN'), ('beginning', 'VBG'), ('next', 'JJ'), ('September', 'NNP'), ('.', '.')]
# 20  But Mr. Barnum called that `` a worst-case '' scenario .
# [('But', 'CC'), ('Mr.', 'NNP'), ('Barnum', 'NNP'), ('called', 'VBD'), ('that', 'IN'), ('``', '``'), ('a', 'DT'), ('worst-case', 'JJ'), ("''", "''"), ('scenario', 'NN'), ('.', '.')]
# 21  Analysts noted yesterday that Cray Research 's decision to link its $ 98.3 million promissory note to Mr. Cray 's presence will complicate a valuation of the new company .
# [('Analysts', 'NNS'), ('noted', 'VBD'), ('yesterday', 'NN'), ('that', 'IN'), ('Cray', 'NNP'), ('Research', 'NNP'), ("'s", 'POS'), ('decision', 'NN'), ('*', '-NONE-'), ('to', 'TO'), ('link', 'VB'), ('its', 'PRP$'), ('$', '$'), ('98.3', 'CD'), ('million', 'CD'), ('*U*', '-NONE-'), ('promissory', 'JJ'), ('note', 'NN'), ('to', 'TO'), ('Mr.', 'NNP'), ('Cray', 'NNP'), ("'s", 'POS'), ('presence', 'NN'), ('will', 'MD'), ('complicate', 'VB'), ('a', 'DT'), ('valuation', 'NN'), ('of', 'IN'), ('the', 'DT'), ('new', 'JJ'), ('company', 'NN'), ('.', '.')]
# 22  Mrs. Hills said many of the 25 countries that she placed under varying degrees of scrutiny have made `` genuine progress '' on this touchy issue .
# [('Mrs.', 'NNP'), ('Hills', 'NNP'), ('said', 'VBD'), ('0', '-NONE-'), ('many', 'JJ'), ('of', 'IN'), ('the', 'DT'), ('25', 'CD'), ('countries', 'NNS'), ('that', 'IN'), ('she', 'PRP'), ('placed', 'VBD'), ('*T*-1', '-NONE-'), ('under', 'IN'), ('varying', 'VBG'), ('degrees', 'NNS'), ('of', 'IN'), ('scrutiny', 'NN'), ('have', 'VBP'), ('made', 'VBN'), ('``', '``'), ('genuine', 'JJ'), ('progress', 'NN'), ("''", "''"), ('on', 'IN'), ('this', 'DT'), ('touchy', 'JJ'), ('issue', 'NN'), ('.', '.')]
# 23  U.S. trade negotiators argue that countries with inadequate protections for intellectual-property rights could be hurting themselves by discouraging their own scientists and authors and by deterring U.S. high-technology firms from investing or marketing their best products there .
# [('U.S.', 'NNP'), ('trade', 'NN'), ('negotiators', 'NNS'), ('argue', 'VBP'), ('that', 'IN'), ('countries', 'NNS'), ('with', 'IN'), ('inadequate', 'JJ'), ('protections', 'NNS'), ('for', 'IN'), ('intellectual-property', 'JJ'), ('rights', 'NNS'), ('could', 'MD'), ('be', 'VB'), ('hurting', 'VBG'), ('themselves', 'PRP'), ('by', 'IN'), ('*-1', '-NONE-'), ('discouraging', 'VBG'), ('their', 'PRP$'), ('own', 'JJ'), ('scientists', 'NNS'), ('and', 'CC'), ('authors', 'NNS'), ('and', 'CC'), ('by', 'IN'), ('*-1', '-NONE-'), ('deterring', 'VBG'), ('U.S.', 'NNP'), ('high-technology', 'NN'), ('firms', 'NNS'), ('from', 'IN'), ('*-2', '-NONE-'), ('investing', 'VBG'), ('or', 'CC'), ('marketing', 'VBG'), ('their', 'PRP$'), ('best', 'JJS'), ('products', 'NNS'), ('there', 'RB'), ('.', '.')]
# 24  Gary Hoffman , a Washington lawyer specializing in intellectual-property cases , said the threat of U.S. retaliation , combined with a growing recognition that protecting intellectual property is in a country 's own interest , prompted the improvements made by South Korea , Taiwan and Saudi Arabia .
# [('Gary', 'NNP'), ('Hoffman', 'NNP'), (',', ','), ('a', 'DT'), ('Washington', 'NNP'), ('lawyer', 'NN'), ('specializing', 'VBG'), ('in', 'IN'), ('intellectual-property', 'JJ'), ('cases', 'NNS'), (',', ','), ('said', 'VBD'), ('0', '-NONE-'), ('the', 'DT'), ('threat', 'NN'), ('of', 'IN'), ('U.S.', 'NNP'), ('retaliation', 'NN'), (',', ','), ('combined', 'VBN'), ('*', '-NONE-'), ('with', 'IN'), ('a', 'DT'), ('growing', 'VBG'), ('recognition', 'NN'), ('that', 'IN'), ('*', '-NONE-'), ('protecting', 'VBG'), ('intellectual', 'JJ'), ('property', 'NN'), ('is', 'VBZ'), ('in', 'IN'), ('a', 'DT'), ('country', 'NN'), ("'s", 'POS'), ('own', 'JJ'), ('interest', 'NN'), (',', ','), ('prompted', 'VBD'), ('the', 'DT'), ('improvements', 'NNS'), ('made', 'VBN'), ('*', '-NONE-'), ('by', 'IN'), ('South', 'NNP'), ('Korea', 'NNP'), (',', ','), ('Taiwan', 'NNP'), ('and', 'CC'), ('Saudi', 'NNP'), ('Arabia', 'NNP'), ('.', '.')]
# 25  Mrs. Hills said that the U.S. is still concerned about `` disturbing developments in Turkey and continuing slow progress in Malaysia . ''
# [('Mrs.', 'NNP'), ('Hills', 'NNP'), ('said', 'VBD'), ('that', 'IN'), ('the', 'DT'), ('U.S.', 'NNP'), ('is', 'VBZ'), ('still', 'RB'), ('concerned', 'VBN'), ('about', 'IN'), ('``', '``'), ('disturbing', 'JJ'), ('developments', 'NNS'), ('in', 'IN'), ('Turkey', 'NNP'), ('and', 'CC'), ('continuing', 'VBG'), ('slow', 'JJ'), ('progress', 'NN'), ('in', 'IN'), ('Malaysia', 'NNP'), ('.', '.'), ("''", "''")]
# 26  But he has not said before that the country wants half the debt forgiven .
# [('But', 'CC'), ('he', 'PRP'), ('has', 'VBZ'), ('not', 'RB'), ('said', 'VBD'), ('before', 'IN'), ('that', 'IN'), ('the', 'DT'), ('country', 'NN'), ('wants', 'VBZ'), ('half', 'PDT'), ('the', 'DT'), ('debt', 'NN'), ('forgiven', 'VBN'), ('*-2', '-NONE-'), ('.', '.')]
# 27  What 's so wild about the funds ' frenzy right now is that many are trading at historically fat premiums to the value of their underlying portfolios .
# [('What', 'WP'), ('*ICH*-1', '-NONE-'), ('*T*-41', '-NONE-'), ("'s", 'VBZ'), ('so', 'RB'), ('wild', 'JJ'), ('about', 'IN'), ('the', 'DT'), ('funds', 'NNS'), ("'", 'POS'), ('frenzy', 'NN'), ('right', 'RB'), ('now', 'RB'), ('is', 'VBZ'), ('that', 'IN'), ('many', 'JJ'), ('are', 'VBP'), ('trading', 'VBG'), ('at', 'IN'), ('historically', 'RB'), ('fat', 'JJ'), ('premiums', 'NNS'), ('to', 'TO'), ('the', 'DT'), ('value', 'NN'), ('of', 'IN'), ('their', 'PRP$'), ('underlying', 'JJ'), ('portfolios', 'NNS'), ('.', '.')]
# 28  They argue that U.S. investors often can buy American depositary receipts on the big stocks in many funds ; these so-called ADRs represent shares of foreign companies traded in the U.S. .
# [('They', 'PRP'), ('argue', 'VBP'), ('that', 'IN'), ('U.S.', 'NNP'), ('investors', 'NNS'), ('often', 'RB'), ('can', 'MD'), ('buy', 'VB'), ('American', 'JJ'), ('depositary', 'JJ'), ('receipts', 'NNS'), ('on', 'IN'), ('the', 'DT'), ('big', 'JJ'), ('stocks', 'NNS'), ('in', 'IN'), ('many', 'JJ'), ('funds', 'NNS'), (';', ':'), ('these', 'DT'), ('so-called', 'JJ'), ('ADRs', 'NNPS'), ('represent', 'VBP'), ('shares', 'NNS'), ('of', 'IN'), ('foreign', 'JJ'), ('companies', 'NNS'), ('traded', 'VBN'), ('*', '-NONE-'), ('in', 'IN'), ('the', 'DT'), ('U.S.', 'NNP'), ('.', '.')]
# 29  For people who insist on jumping in now to buy the funds , Newgate 's Mr. Foot says : `` The only advice I have for these folks is that those who come to the party late had better be ready to leave quickly .
# [('For', 'IN'), ('people', 'NNS'), ('who', 'WP'), ('*T*-45', '-NONE-'), ('insist', 'VBP'), ('on', 'RP'), ('*-5', '-NONE-'), ('jumping', 'VBG'), ('in', 'RB'), ('now', 'RB'), ('*-1', '-NONE-'), ('to', 'TO'), ('buy', 'VB'), ('the', 'DT'), ('funds', 'NNS'), (',', ','), ('Newgate', 'NNP'), ("'s", 'POS'), ('Mr.', 'NNP'), ('Foot', 'NNP'), ('says', 'VBZ'), (':', ':'), ('``', '``'), ('The', 'DT'), ('only', 'JJ'), ('advice', 'NN'), ('0', '-NONE-'), ('I', 'PRP'), ('have', 'VBP'), ('*T*-2', '-NONE-'), ('for', 'IN'), ('these', 'DT'), ('folks', 'NNS'), ('is', 'VBZ'), ('that', 'IN'), ('those', 'DT'), ('who', 'WP'), ('*T*-3', '-NONE-'), ('come', 'VBP'), ('to', 'TO'), ('the', 'DT'), ('party', 'NN'), ('late', 'RB'), ('had', 'VBD'), ('better', 'RBR'), ('*-4', '-NONE-'), ('be', 'VB'), ('ready', 'JJ'), ('*-4', '-NONE-'), ('to', 'TO'), ('leave', 'VB'), ('quickly', 'RB'), ('.', '.')]
# 30  However , after two meetings with the Soviets , a State Department spokesman said that it 's `` too early to say '' whether that will happen .
# [('However', 'RB'), (',', ','), ('after', 'IN'), ('two', 'CD'), ('meetings', 'NNS'), ('with', 'IN'), ('the', 'DT'), ('Soviets', 'NNS'), (',', ','), ('a', 'DT'), ('State', 'NNP'), ('Department', 'NNP'), ('spokesman', 'NN'), ('said', 'VBD'), ('that', 'IN'), ('it', 'PRP'), ('*EXP*-1', '-NONE-'), ("'s", 'VBZ'), ('``', '``'), ('too', 'RB'), ('early', 'RB'), ('*', '-NONE-'), ('to', 'TO'), ('say', 'VB'), ("''", "''"), ('whether', 'IN'), ('that', 'DT'), ('will', 'MD'), ('happen', 'VB'), ('.', '.')]
# 31  In another reflection that the growth of the economy is leveling off , the government said that orders for manufactured goods and spending on construction failed to rise in September .
# [('In', 'IN'), ('another', 'DT'), ('reflection', 'NN'), ('that', 'IN'), ('the', 'DT'), ('growth', 'NN'), ('of', 'IN'), ('the', 'DT'), ('economy', 'NN'), ('is', 'VBZ'), ('leveling', 'VBG'), ('off', 'RP'), (',', ','), ('the', 'DT'), ('government', 'NN'), ('said', 'VBD'), ('that', 'IN'), ('orders', 'NNS'), ('for', 'IN'), ('manufactured', 'VBN'), ('goods', 'NNS'), ('and', 'CC'), ('spending', 'NN'), ('on', 'IN'), ('construction', 'NN'), ('failed', 'VBD'), ('*-1', '-NONE-'), ('to', 'TO'), ('rise', 'VB'), ('in', 'IN'), ('September', 'NNP'), ('.', '.')]
# 32  Meanwhile , the National Association of Purchasing Management said its latest survey indicated that the manufacturing economy contracted in October for the sixth consecutive month .
# [('Meanwhile', 'RB'), (',', ','), ('the', 'DT'), ('National', 'NNP'), ('Association', 'NNP'), ('of', 'IN'), ('Purchasing', 'NNP'), ('Management', 'NNP'), ('said', 'VBD'), ('0', '-NONE-'), ('its', 'PRP$'), ('latest', 'JJS'), ('survey', 'NN'), ('indicated', 'VBD'), ('that', 'IN'), ('the', 'DT'), ('manufacturing', 'NN'), ('economy', 'NN'), ('contracted', 'VBD'), ('in', 'IN'), ('October', 'NNP'), ('for', 'IN'), ('the', 'DT'), ('sixth', 'JJ'), ('consecutive', 'JJ'), ('month', 'NN'), ('.', '.')]
# 33  The purchasing managers , however , also said that orders turned up in October after four months of decline .
# [('The', 'DT'), ('purchasing', 'VBG'), ('managers', 'NNS'), (',', ','), ('however', 'RB'), (',', ','), ('also', 'RB'), ('said', 'VBD'), ('that', 'IN'), ('orders', 'NNS'), ('turned', 'VBD'), ('up', 'RB'), ('in', 'IN'), ('October', 'NNP'), ('after', 'IN'), ('four', 'CD'), ('months', 'NNS'), ('of', 'IN'), ('decline', 'NN'), ('.', '.')]
# 34  Yet many economists are n't predicting that the economy is about to slip into recession .
# [('Yet', 'CC'), ('many', 'JJ'), ('economists', 'NNS'), ('are', 'VBP'), ("n't", 'RB'), ('predicting', 'VBG'), ('that', 'IN'), ('the', 'DT'), ('economy', 'NN'), ('is', 'VBZ'), ('about', 'IN'), ('*-1', '-NONE-'), ('to', 'TO'), ('slip', 'VB'), ('into', 'IN'), ('recession', 'NN'), ('.', '.')]
# 35  `` I do n't see any signs that inventories are excessive . ''
# [('``', '``'), ('I', 'PRP'), ('do', 'VBP'), ("n't", 'RB'), ('see', 'VB'), ('any', 'DT'), ('signs', 'NNS'), ('that', 'IN'), ('inventories', 'NNS'), ('are', 'VBP'), ('excessive', 'JJ'), ('.', '.'), ("''", "''")]
# 36  The department previously estimated that durable-goods orders fell 0.1 % in September .
# [('The', 'DT'), ('department', 'NN'), ('previously', 'RB'), ('estimated', 'VBD'), ('that', 'IN'), ('durable-goods', 'NNS'), ('orders', 'NNS'), ('fell', 'VBD'), ('0.1', 'CD'), ('%', 'NN'), ('in', 'IN'), ('September', 'NNP'), ('.', '.')]
# 37  The report offered new evidence that the nation 's export growth , though still continuing , may be slowing .
# [('The', 'DT'), ('report', 'NN'), ('offered', 'VBD'), ('new', 'JJ'), ('evidence', 'NN'), ('that', 'IN'), ('the', 'DT'), ('nation', 'NN'), ("'s", 'POS'), ('export', 'NN'), ('growth', 'NN'), (',', ','), ('though', 'IN'), ('*-1', '-NONE-'), ('still', 'RB'), ('continuing', 'VBG'), (',', ','), ('may', 'MD'), ('be', 'VB'), ('slowing', 'VBG'), ('.', '.')]
# 38  The purhasing managers ' report also added evidence that inflation is under control .
# [('The', 'DT'), ('purhasing', 'NN'), ('managers', 'NNS'), ("'", 'POS'), ('report', 'NN'), ('also', 'RB'), ('added', 'VBD'), ('evidence', 'NN'), ('that', 'IN'), ('inflation', 'NN'), ('is', 'VBZ'), ('under', 'IN'), ('control', 'NN'), ('.', '.')]
# 39  They also said that vendors were delivering goods more quickly in October than they had for each of the five previous months .
# [('They', 'PRP'), ('also', 'RB'), ('said', 'VBD'), ('that', 'IN'), ('vendors', 'NNS'), ('were', 'VBD'), ('delivering', 'VBG'), ('goods', 'NNS'), ('more', 'RBR'), ('quickly', 'RB'), ('*ICH*-1', '-NONE-'), ('in', 'IN'), ('October', 'NNP'), ('than', 'IN'), ('they', 'PRP'), ('had', 'VBD'), ('*?*', '-NONE-'), ('for', 'IN'), ('each', 'DT'), ('of', 'IN'), ('the', 'DT'), ('five', 'CD'), ('previous', 'JJ'), ('months', 'NNS'), ('.', '.')]
# 40  Economists consider that a sign that inflationary pressures are abating .
# [('Economists', 'NNS'), ('consider', 'VBP'), ('that', 'DT'), ('a', 'DT'), ('sign', 'NN'), ('that', 'IN'), ('inflationary', 'JJ'), ('pressures', 'NNS'), ('are', 'VBP'), ('abating', 'VBG'), ('.', '.')]
# 41  It found that of the 73 % who import , 10 % said they imported more in October and 12 % said they imported less than the previous month .
# [('It', 'PRP'), ('found', 'VBD'), ('that', 'IN'), ('of', 'IN'), ('the', 'DT'), ('73', 'CD'), ('%', 'NN'), ('who', 'WP'), ('*T*-51', '-NONE-'), ('import', 'VBP'), (',', ','), ('10', 'CD'), ('%', 'NN'), ('*T*-1', '-NONE-'), ('said', 'VBD'), ('0', '-NONE-'), ('they', 'PRP'), ('imported', 'VBD'), ('more', 'RBR'), ('in', 'IN'), ('October', 'NNP'), ('and', 'CC'), ('12', 'CD'), ('%', 'NN'), ('*T*-1', '-NONE-'), ('said', 'VBD'), ('0', '-NONE-'), ('they', 'PRP'), ('imported', 'VBD'), ('less', 'JJR'), ('than', 'IN'), ('the', 'DT'), ('previous', 'JJ'), ('month', 'NN'), ('.', '.')]
# 42  He said that for the second month in a row , food processors reported a shortage of nonfat dry milk .
# [('He', 'PRP'), ('said', 'VBD'), ('that', 'IN'), ('for', 'IN'), ('the', 'DT'), ('second', 'JJ'), ('month', 'NN'), ('in', 'IN'), ('a', 'DT'), ('row', 'NN'), (',', ','), ('food', 'NN'), ('processors', 'NNS'), ('reported', 'VBD'), ('a', 'DT'), ('shortage', 'NN'), ('of', 'IN'), ('nonfat', 'JJ'), ('dry', 'JJ'), ('milk', 'NN'), ('.', '.')]
# 43  For an American reader , part of the charm of this engaging novel should come in recognizing that Japan is n't the buttoned-down society of contemporary American lore .
# [('For', 'IN'), ('an', 'DT'), ('American', 'JJ'), ('reader', 'NN'), (',', ','), ('part', 'NN'), ('of', 'IN'), ('the', 'DT'), ('charm', 'NN'), ('of', 'IN'), ('this', 'DT'), ('engaging', 'JJ'), ('novel', 'NN'), ('should', 'MD'), ('come', 'VB'), ('in', 'IN'), ('*', '-NONE-'), ('recognizing', 'VBG'), ('that', 'IN'), ('Japan', 'NNP'), ('is', 'VBZ'), ("n't", 'RB'), ('the', 'DT'), ('buttoned-down', 'JJ'), ('society', 'NN'), ('of', 'IN'), ('contemporary', 'JJ'), ('American', 'JJ'), ('lore', 'NN'), ('.', '.')]
# 44  If `` A Wild Sheep Chase '' carries an implicit message for international relations , it 's that the Japanese are more like us than most of us think .
# [('If', 'IN'), ('``', '``'), ('A', 'DT'), ('Wild', 'NNP'), ('Sheep', 'NNP'), ('Chase', 'NNP'), ("''", "''"), ('carries', 'VBZ'), ('an', 'DT'), ('implicit', 'JJ'), ('message', 'NN'), ('for', 'IN'), ('international', 'JJ'), ('relations', 'NNS'), (',', ','), ('it', 'PRP'), ("'s", 'VBZ'), ('that', 'IN'), ('the', 'DT'), ('Japanese', 'NNS'), ('are', 'VBP'), ('more', 'RBR'), ('like', 'IN'), ('us', 'PRP'), ('than', 'IN'), ('most', 'JJS'), ('of', 'IN'), ('us', 'PRP'), ('think', 'VBP'), ('0', '-NONE-'), ('*?*', '-NONE-'), ('.', '.')]
# 45  That 's not to say that the nutty plot of `` A Wild Sheep Chase '' is rooted in reality .
# [('That', 'DT'), ("'s", 'VBZ'), ('not', 'RB'), ('*', '-NONE-'), ('to', 'TO'), ('say', 'VB'), ('that', 'IN'), ('the', 'DT'), ('nutty', 'JJ'), ('plot', 'NN'), ('of', 'IN'), ('``', '``'), ('A', 'DT'), ('Wild', 'NNP'), ('Sheep', 'NNP'), ('Chase', 'NNP'), ("''", "''"), ('is', 'VBZ'), ('rooted', 'VBN'), ('*-57', '-NONE-'), ('in', 'IN'), ('reality', 'NN'), ('.', '.')]
# 46  It 's probably true that many salarymen put in unproductive overtime just for the sake of solidarity , that the system is so hierarchical that only the assistant manager can talk to the manager and the manager to the general manager , and that Sony was chary of letting a young , short-term American employee take on any responsibility .
# [('It', 'PRP'), ('*EXP*-3', '-NONE-'), ("'s", 'VBZ'), ('probably', 'RB'), ('true', 'JJ'), ('that', 'IN'), ('many', 'JJ'), ('salarymen', 'NNS'), ('put', 'VBN'), ('in', 'RP'), ('unproductive', 'JJ'), ('overtime', 'NN'), ('just', 'RB'), ('for', 'IN'), ('the', 'DT'), ('sake', 'NN'), ('of', 'IN'), ('solidarity', 'NN'), (',', ','), ('that', 'IN'), ('the', 'DT'), ('system', 'NN'), ('is', 'VBZ'), ('so', 'RB'), ('hierarchical', 'JJ'), ('that', 'IN'), ('only', 'RB'), ('the', 'DT'), ('assistant', 'JJ'), ('manager', 'NN'), ('can', 'MD'), ('talk', 'VB'), ('to', 'TO'), ('the', 'DT'), ('manager', 'NN'), ('and', 'CC'), ('the', 'DT'), ('manager', 'NN'), ('to', 'TO'), ('the', 'DT'), ('general', 'JJ'), ('manager', 'NN'), (',', ','), ('and', 'CC'), ('that', 'IN'), ('Sony', 'NNP'), ('was', 'VBD'), ('chary', 'JJ'), ('of', 'IN'), ('*-4', '-NONE-'), ('letting', 'VBG'), ('a', 'DT'), ('young', 'JJ'), (',', ','), ('short-term', 'JJ'), ('American', 'JJ'), ('employee', 'NN'), ('take', 'VB'), ('on', 'RP'), ('any', 'DT'), ('responsibility', 'NN'), ('.', '.')]
# 47  A marketing study indicates that Hong Kong consumers are the most materialistic in the 14 major markets where the survey was carried out .
# [('A', 'DT'), ('marketing', 'NN'), ('study', 'NN'), ('indicates', 'VBZ'), ('that', 'IN'), ('Hong', 'NNP'), ('Kong', 'NNP'), ('consumers', 'NNS'), ('are', 'VBP'), ('the', 'DT'), ('most', 'RBS'), ('materialistic', 'JJ'), ('in', 'IN'), ('the', 'DT'), ('14', 'CD'), ('major', 'JJ'), ('markets', 'NNS'), ('where', 'WRB'), ('the', 'DT'), ('survey', 'NN'), ('was', 'VBD'), ('carried', 'VBN'), ('out', 'RP'), ('*T*-1', '-NONE-'), ('.', '.')]
# 48  The study by the Backer Spielvogel Bates ad agency also found that the colony 's consumers feel more pressured than those in any of the other surveyed markets , which include the U.S. and Japan .
# [('The', 'DT'), ('study', 'NN'), ('by', 'IN'), ('the', 'DT'), ('Backer', 'NNP'), ('Spielvogel', 'NNP'), ('Bates', 'NNP'), ('ad', 'NN'), ('agency', 'NN'), ('also', 'RB'), ('found', 'VBD'), ('that', 'IN'), ('the', 'DT'), ('colony', 'NN'), ("'s", 'POS'), ('consumers', 'NNS'), ('feel', 'VBP'), ('more', 'RBR'), ('pressured', 'JJ'), ('than', 'IN'), ('those', 'DT'), ('in', 'IN'), ('any', 'DT'), ('of', 'IN'), ('the', 'DT'), ('other', 'JJ'), ('surveyed', 'VBN'), ('markets', 'NNS'), (',', ','), ('which', 'WDT'), ('*T*-60', '-NONE-'), ('include', 'VBP'), ('the', 'DT'), ('U.S.', 'NNP'), ('and', 'CC'), ('Japan', 'NNP'), ('.', '.')]
# 49  The survey found that nearly half of Hong Kong consumers espouse what it identified as materialistic values , compared with about one-third in Japan and the U.S. .
# [('The', 'DT'), ('survey', 'NN'), ('found', 'VBD'), ('that', 'IN'), ('nearly', 'RB'), ('half', 'NN'), ('of', 'IN'), ('Hong', 'NNP'), ('Kong', 'NNP'), ('consumers', 'NNS'), ('espouse', 'VBP'), ('what', 'WP'), ('it', 'PRP'), ('identified', 'VBD'), ('*T*-61', '-NONE-'), ('as', 'IN'), ('materialistic', 'JJ'), ('values', 'NNS'), (',', ','), ('compared', 'VBN'), ('with', 'IN'), ('about', 'RB'), ('one-third', 'JJ'), ('in', 'IN'), ('Japan', 'NNP'), ('and', 'CC'), ('the', 'DT'), ('U.S.', 'NNP'), ('.', '.')]
# 50  Mr. Nemeth said in parliament that Czechoslovakia and Hungary would suffer environmental damage if the twin dams were built as planned .
# [('Mr.', 'NNP'), ('Nemeth', 'NNP'), ('said', 'VBD'), ('in', 'IN'), ('parliament', 'NN'), ('that', 'IN'), ('Czechoslovakia', 'NNP'), ('and', 'CC'), ('Hungary', 'NNP'), ('would', 'MD'), ('suffer', 'VB'), ('environmental', 'JJ'), ('damage', 'NN'), ('if', 'IN'), ('the', 'DT'), ('twin', 'NN'), ('dams', 'NNS'), ('were', 'VBD'), ('built', 'VBN'), ('*-67', '-NONE-'), ('as', 'IN'), ('*', '-NONE-'), ('planned', 'VBN'), ('*-2', '-NONE-'), ('.', '.')]
# 51  Japanese press reports have speculated that the Japanese contribution could rise to between 20 % and 25 % under the new program .
# [('Japanese', 'JJ'), ('press', 'NN'), ('reports', 'NNS'), ('have', 'VBP'), ('speculated', 'VBN'), ('that', 'IN'), ('the', 'DT'), ('Japanese', 'JJ'), ('contribution', 'NN'), ('could', 'MD'), ('rise', 'VB'), ('to', 'TO'), ('between', 'IN'), ('20', 'CD'), ('%', 'NN'), ('and', 'CC'), ('25', 'CD'), ('%', 'NN'), ('*U*', '-NONE-'), ('under', 'IN'), ('the', 'DT'), ('new', 'JJ'), ('program', 'NN'), ('.', '.')]
# 52  The irony is that the attack commercial , after getting a boost in last year 's presidential campaign , has come of age in an off-off election year with only a few contests scattered across the country .
# [('The', 'DT'), ('irony', 'NN'), ('is', 'VBZ'), ('that', 'IN'), ('the', 'DT'), ('attack', 'NN'), ('commercial', 'NN'), (',', ','), ('after', 'IN'), ('*-1', '-NONE-'), ('getting', 'VBG'), ('a', 'DT'), ('boost', 'NN'), ('in', 'IN'), ('last', 'JJ'), ('year', 'NN'), ("'s", 'POS'), ('presidential', 'JJ'), ('campaign', 'NN'), (',', ','), ('has', 'VBZ'), ('come', 'VBN'), ('of', 'IN'), ('age', 'NN'), ('in', 'IN'), ('an', 'DT'), ('off-off', 'JJ'), ('election', 'NN'), ('year', 'NN'), ('with', 'IN'), ('only', 'RB'), ('a', 'DT'), ('few', 'JJ'), ('contests', 'NNS'), ('scattered', 'VBN'), ('*', '-NONE-'), ('across', 'IN'), ('the', 'DT'), ('country', 'NN'), ('.', '.')]
# 53  But in the three leading political contests of 1989 , the negative ads have reached new levels of hostility , raising fears that this kind of mudslinging , empty of significant issues , is ushering in a new era of campaigns without content .
# [('But', 'IN'), ('in', 'IN'), ('the', 'DT'), ('three', 'CD'), ('leading', 'VBG'), ('political', 'JJ'), ('contests', 'NNS'), ('of', 'IN'), ('1989', 'CD'), (',', ','), ('the', 'DT'), ('negative', 'JJ'), ('ads', 'NNS'), ('have', 'VBP'), ('reached', 'VBN'), ('new', 'JJ'), ('levels', 'NNS'), ('of', 'IN'), ('hostility', 'NN'), (',', ','), ('*-1', '-NONE-'), ('raising', 'VBG'), ('fears', 'NNS'), ('that', 'IN'), ('this', 'DT'), ('kind', 'NN'), ('of', 'IN'), ('mudslinging', 'NN'), (',', ','), ('empty', 'JJ'), ('of', 'IN'), ('significant', 'JJ'), ('issues', 'NNS'), (',', ','), ('is', 'VBZ'), ('ushering', 'VBG'), ('in', 'IN'), ('a', 'DT'), ('new', 'JJ'), ('era', 'NN'), ('of', 'IN'), ('campaigns', 'NNS'), ('without', 'IN'), ('content', 'NN'), ('.', '.')]
# 54  They know he is generally opposed to cop-killer bullets , but that he had some reservations about the language in the legislation . ''
# [('They', 'PRP'), ('know', 'VBP'), ('0', '-NONE-'), ('he', 'PRP'), ('is', 'VBZ'), ('generally', 'RB'), ('opposed', 'VBN'), ('to', 'TO'), ('cop-killer', 'JJ'), ('bullets', 'NNS'), (',', ','), ('but', 'CC'), ('that', 'IN'), ('he', 'PRP'), ('had', 'VBD'), ('some', 'DT'), ('reservations', 'NNS'), ('about', 'IN'), ('the', 'DT'), ('language', 'NN'), ('in', 'IN'), ('the', 'DT'), ('legislation', 'NN'), ('.', '.'), ("''", "''")]
# 55  Democratic Lt. Gov. Douglas Wilder opened his gubernatorial battle with Republican Marshall Coleman with an abortion commercial produced by Frank Greer that analysts of every political persuasion agree was a tour de force .
# [('Democratic', 'JJ'), ('Lt.', 'NNP'), ('Gov.', 'NNP'), ('Douglas', 'NNP'), ('Wilder', 'NNP'), ('opened', 'VBD'), ('his', 'PRP$'), ('gubernatorial', 'JJ'), ('battle', 'NN'), ('with', 'IN'), ('Republican', 'JJ'), ('Marshall', 'NNP'), ('Coleman', 'NNP'), ('with', 'IN'), ('an', 'DT'), ('abortion', 'NN'), ('commercial', 'NN'), ('produced', 'VBN'), ('*', '-NONE-'), ('by', 'IN'), ('Frank', 'NNP'), ('Greer', 'NNP'), ('that', 'IN'), ('analysts', 'NNS'), ('of', 'IN'), ('every', 'DT'), ('political', 'JJ'), ('persuasion', 'NN'), ('agree', 'VBP'), ('0', '-NONE-'), ('*T*-1', '-NONE-'), ('was', 'VBD'), ('a', 'DT'), ('tour', 'NN'), ('de', 'FW'), ('force', 'NN'), ('.', '.')]
# 56  Against a shot of Monticello superimposed on an American flag , an announcer talks about the `` strong tradition of freedom and individual liberty '' that Virginians have nurtured for generations .
# [('Against', 'IN'), ('a', 'DT'), ('shot', 'NN'), ('of', 'IN'), ('Monticello', 'NNP'), ('superimposed', 'VBN'), ('*', '-NONE-'), ('on', 'IN'), ('an', 'DT'), ('American', 'JJ'), ('flag', 'NN'), (',', ','), ('an', 'DT'), ('announcer', 'NN'), ('talks', 'VBZ'), ('about', 'IN'), ('the', 'DT'), ('``', '``'), ('strong', 'JJ'), ('tradition', 'NN'), ('of', 'IN'), ('freedom', 'NN'), ('and', 'CC'), ('individual', 'JJ'), ('liberty', 'NN'), ("''", "''"), ('that', 'IN'), ('Virginians', 'NNPS'), ('have', 'VBP'), ('nurtured', 'VBN'), ('*T*-1', '-NONE-'), ('for', 'IN'), ('generations', 'NNS'), ('.', '.')]
# 57  The Coleman counterattack featured a close-up of a young woman in shadows and the ad suggested that she was recalling an unpleasant courtroom ordeal .
# [('The', 'DT'), ('Coleman', 'NNP'), ('counterattack', 'NN'), ('featured', 'VBD'), ('a', 'DT'), ('close-up', 'NN'), ('of', 'IN'), ('a', 'DT'), ('young', 'JJ'), ('woman', 'NN'), ('in', 'IN'), ('shadows', 'NNS'), ('and', 'CC'), ('the', 'DT'), ('ad', 'NN'), ('suggested', 'VBD'), ('that', 'IN'), ('she', 'PRP'), ('was', 'VBD'), ('recalling', 'VBG'), ('an', 'DT'), ('unpleasant', 'JJ'), ('courtroom', 'NN'), ('ordeal', 'NN'), ('.', '.')]
# 58  The legislation itself noted that it was introduced `` by request , '' and in 1983 Mr. Wilder introduced a bill to protect rape victims from unfounded interrogation .
# [('The', 'DT'), ('legislation', 'NN'), ('itself', 'PRP'), ('noted', 'VBD'), ('that', 'IN'), ('it', 'PRP'), ('was', 'VBD'), ('introduced', 'VBN'), ('*-1', '-NONE-'), ('``', '``'), ('by', 'IN'), ('request', 'NN'), (',', ','), ("''", "''"), ('and', 'CC'), ('in', 'IN'), ('1983', 'CD'), ('Mr.', 'NNP'), ('Wilder', 'NNP'), ('introduced', 'VBD'), ('a', 'DT'), ('bill', 'NN'), ('0', '-NONE-'), ('*T*-2', '-NONE-'), ('to', 'TO'), ('protect', 'VB'), ('rape', 'NN'), ('victims', 'NNS'), ('from', 'IN'), ('unfounded', 'JJ'), ('interrogation', 'NN'), ('.', '.')]
# 59  `` Wilder has managed to get across the idea that Coleman will say anything to get elected governor and -- more important -- has been able to put the onus for all the negative campaigning on Coleman . ''
# [('``', '``'), ('Wilder', 'NNP'), ('has', 'VBZ'), ('managed', 'VBN'), ('*-1', '-NONE-'), ('to', 'TO'), ('get', 'VB'), ('across', 'RP'), ('the', 'DT'), ('idea', 'NN'), ('that', 'IN'), ('Coleman', 'NNP'), ('will', 'MD'), ('say', 'VB'), ('anything', 'NN'), ('*-2', '-NONE-'), ('to', 'TO'), ('get', 'VB'), ('elected', 'VBN'), ('*-3', '-NONE-'), ('governor', 'NN'), ('and', 'CC'), ('--', ':'), ('more', 'RBR'), ('important', 'JJ'), ('--', ':'), ('has', 'VBZ'), ('been', 'VBN'), ('able', 'JJ'), ('*-1', '-NONE-'), ('to', 'TO'), ('put', 'VB'), ('the', 'DT'), ('onus', 'NN'), ('for', 'IN'), ('all', 'PDT'), ('the', 'DT'), ('negative', 'JJ'), ('campaigning', 'NN'), ('on', 'IN'), ('Coleman', 'NNP'), ('.', '.'), ("''", "''")]
# 60  Mr. Coleman said this week that he would devote the remainder of the political season to positive campaigning , but the truce lasted only hours .
# [('Mr.', 'NNP'), ('Coleman', 'NNP'), ('said', 'VBD'), ('this', 'DT'), ('week', 'NN'), ('that', 'IN'), ('he', 'PRP'), ('would', 'MD'), ('devote', 'VB'), ('the', 'DT'), ('remainder', 'NN'), ('of', 'IN'), ('the', 'DT'), ('political', 'JJ'), ('season', 'NN'), ('to', 'TO'), ('positive', 'JJ'), ('campaigning', 'NN'), (',', ','), ('but', 'CC'), ('the', 'DT'), ('truce', 'NN'), ('lasted', 'VBD'), ('only', 'RB'), ('hours', 'NNS'), ('.', '.')]
# 61  Interviews with analysts and business people in the U.S. suggest that Japanese capital may produce the economic cooperation that Southeast Asian politicians have pursued in fits and starts for decades .
# [('Interviews', 'NNS'), ('with', 'IN'), ('analysts', 'NNS'), ('and', 'CC'), ('business', 'NN'), ('people', 'NNS'), ('in', 'IN'), ('the', 'DT'), ('U.S.', 'NNP'), ('suggest', 'VBP'), ('that', 'IN'), ('Japanese', 'JJ'), ('capital', 'NN'), ('may', 'MD'), ('produce', 'VB'), ('the', 'DT'), ('economic', 'JJ'), ('cooperation', 'NN'), ('that', 'IN'), ('Southeast', 'JJ'), ('Asian', 'JJ'), ('politicians', 'NNS'), ('have', 'VBP'), ('pursued', 'VBN'), ('*T*-2', '-NONE-'), ('in', 'IN'), ('fits', 'NNS'), ('and', 'CC'), ('starts', 'NNS'), ('for', 'IN'), ('decades', 'NNS'), ('.', '.')]
# 62  `` There 's an understanding on the part of the U.S. that Japan has to expand its functions '' in Asia , says J. Michael Farren , undersecretary of commerce for trade .
# [('``', '``'), ('There', 'EX'), ("'s", 'VBZ'), ('an', 'DT'), ('understanding', 'NN'), ('*ICH*-1', '-NONE-'), ('on', 'IN'), ('the', 'DT'), ('part', 'NN'), ('of', 'IN'), ('the', 'DT'), ('U.S.', 'NNP'), ('that', 'IN'), ('Japan', 'NNP'), ('has', 'VBZ'), ('*-2', '-NONE-'), ('to', 'TO'), ('expand', 'VB'), ('its', 'PRP$'), ('functions', 'NNS'), ("''", "''"), ('in', 'IN'), ('Asia', 'NNP'), (',', ','), ('says', 'VBZ'), ('0', '-NONE-'), ('*T*-3', '-NONE-'), ('J.', 'NNP'), ('Michael', 'NNP'), ('Farren', 'NNP'), (',', ','), ('undersecretary', 'NN'), ('of', 'IN'), ('commerce', 'NN'), ('for', 'IN'), ('trade', 'NN'), ('.', '.')]
# 63  Some Asian nations are apprehensive about Washington 's demand that Tokyo step up its military spending to ease the U.S. security burden in the region .
# [('Some', 'DT'), ('Asian', 'JJ'), ('nations', 'NNS'), ('are', 'VBP'), ('apprehensive', 'JJ'), ('about', 'IN'), ('Washington', 'NNP'), ("'s", 'POS'), ('demand', 'NN'), ('that', 'IN'), ('Tokyo', 'NNP'), ('step', 'VB'), ('up', 'RP'), ('its', 'PRP$'), ('military', 'JJ'), ('spending', 'NN'), ('*-1', '-NONE-'), ('to', 'TO'), ('ease', 'VB'), ('the', 'DT'), ('U.S.', 'NNP'), ('security', 'NN'), ('burden', 'NN'), ('in', 'IN'), ('the', 'DT'), ('region', 'NN'), ('.', '.')]
# 64  In her wake she left the bitterness and anger of a principal who was her friend and now calls her a betrayer ; of colleagues who say she brought them shame ; of students and parents who defended her and insist she was treated harshly ; and of school-district officials stunned that despite the bald-faced nature of her actions , she became something of a local martyr .
# [('In', 'IN'), ('her', 'PRP$'), ('wake', 'NN'), ('she', 'PRP'), ('left', 'VBD'), ('the', 'DT'), ('bitterness', 'NN'), ('and', 'CC'), ('anger', 'NN'), ('of', 'IN'), ('a', 'DT'), ('principal', 'NN'), ('who', 'WP'), ('*T*-81', '-NONE-'), ('was', 'VBD'), ('her', 'PRP$'), ('friend', 'NN'), ('and', 'CC'), ('now', 'RB'), ('calls', 'VBZ'), ('her', 'PRP'), ('a', 'DT'), ('betrayer', 'NN'), (';', ':'), ('of', 'IN'), ('colleagues', 'NNS'), ('who', 'WP'), ('*T*-82', '-NONE-'), ('say', 'VBP'), ('0', '-NONE-'), ('she', 'PRP'), ('brought', 'VBD'), ('them', 'PRP'), ('shame', 'NN'), (';', ':'), ('of', 'IN'), ('students', 'NNS'), ('and', 'CC'), ('parents', 'NNS'), ('who', 'WP'), ('*T*-83', '-NONE-'), ('defended', 'VBD'), ('her', 'PRP'), ('and', 'CC'), ('insist', 'VBP'), ('0', '-NONE-'), ('she', 'PRP'), ('was', 'VBD'), ('treated', 'VBN'), ('*-1', '-NONE-'), ('harshly', 'RB'), (';', ':'), ('and', 'CC'), ('of', 'IN'), ('school-district', 'NN'), ('officials', 'NNS'), ('stunned', 'JJ'), ('that', 'IN'), ('despite', 'IN'), ('the', 'DT'), ('bald-faced', 'JJ'), ('nature', 'NN'), ('of', 'IN'), ('her', 'PRP$'), ('actions', 'NNS'), (',', ','), ('she', 'PRP'), ('became', 'VBD'), ('something', 'NN'), ('of', 'IN'), ('a', 'DT'), ('local', 'JJ'), ('martyr', 'NN'), ('.', '.')]
# 65  Prosecutors alleged that she was trying to bolster students ' scores to win a bonus under the state 's 1984 Education Improvement Act .
# [('Prosecutors', 'NNS'), ('alleged', 'VBD'), ('that', 'IN'), ('she', 'PRP'), ('was', 'VBD'), ('trying', 'VBG'), ('*-1', '-NONE-'), ('to', 'TO'), ('bolster', 'VB'), ('students', 'NNS'), ("'", 'POS'), ('scores', 'NNS'), ('*-1', '-NONE-'), ('to', 'TO'), ('win', 'VB'), ('a', 'DT'), ('bonus', 'NN'), ('under', 'IN'), ('the', 'DT'), ('state', 'NN'), ("'s", 'POS'), ('1984', 'CD'), ('Education', 'NNP'), ('Improvement', 'NNP'), ('Act', 'NNP'), ('.', '.')]
# 66  A 50-state study released in September by Friends for Education , an Albuquerque , N.M. , school-research group , concluded that `` outright cheating by American educators '' is `` common . ''
# [('A', 'DT'), ('50-state', 'JJ'), ('study', 'NN'), ('released', 'VBN'), ('*', '-NONE-'), ('in', 'IN'), ('September', 'NNP'), ('by', 'IN'), ('Friends', 'NNPS'), ('for', 'IN'), ('Education', 'NNP'), (',', ','), ('an', 'DT'), ('Albuquerque', 'NNP'), (',', ','), ('N.M.', 'NNP'), (',', ','), ('school-research', 'JJ'), ('group', 'NN'), (',', ','), ('concluded', 'VBD'), ('that', 'IN'), ('``', '``'), ('outright', 'JJ'), ('cheating', 'NN'), ('by', 'IN'), ('American', 'JJ'), ('educators', 'NNS'), ("''", "''"), ('is', 'VBZ'), ('``', '``'), ('common', 'JJ'), ('.', '.'), ("''", "''")]
# 67  Another was Nancy Yeargin , who came to Greenville in 1985 , full of the energy and ambitions that reformers wanted to reward .
# [('Another', 'DT'), ('was', 'VBD'), ('Nancy', 'NNP'), ('Yeargin', 'NNP'), (',', ','), ('who', 'WP'), ('*T*-89', '-NONE-'), ('came', 'VBD'), ('to', 'TO'), ('Greenville', 'NNP'), ('in', 'IN'), ('1985', 'CD'), (',', ','), ('*-1', '-NONE-'), ('full', 'JJ'), ('of', 'IN'), ('the', 'DT'), ('energy', 'NN'), ('and', 'CC'), ('ambitions', 'NNS'), ('that', 'IN'), ('reformers', 'NNS'), ('wanted', 'VBD'), ('*-2', '-NONE-'), ('to', 'TO'), ('reward', 'VB'), ('*T*-3', '-NONE-'), ('.', '.')]
# 68  She says that because of Mrs. Yeargin she gave up ambitions in architecture and is studying to become a teacher .
# [('She', 'PRP'), ('says', 'VBZ'), ('that', 'IN'), ('because', 'IN'), ('of', 'IN'), ('Mrs.', 'NNP'), ('Yeargin', 'NNP'), ('she', 'PRP'), ('gave', 'VBD'), ('up', 'RP'), ('ambitions', 'NNS'), ('in', 'IN'), ('architecture', 'NN'), ('and', 'CC'), ('is', 'VBZ'), ('studying', 'VBG'), ('*-1', '-NONE-'), ('to', 'TO'), ('become', 'VB'), ('a', 'DT'), ('teacher', 'NN'), ('.', '.')]
# 69  Last March , after attending a teaching seminar in Washington , Mrs. Yeargin says she returned to Greenville two days before annual testing feeling that she had n't prepared her low-ability geography students adequately .
# [('Last', 'JJ'), ('March', 'NNP'), (',', ','), ('after', 'IN'), ('*-1', '-NONE-'), ('attending', 'VBG'), ('a', 'DT'), ('teaching', 'NN'), ('seminar', 'NN'), ('in', 'IN'), ('Washington', 'NNP'), (',', ','), ('Mrs.', 'NNP'), ('Yeargin', 'NNP'), ('says', 'VBZ'), ('0', '-NONE-'), ('she', 'PRP'), ('returned', 'VBD'), ('to', 'TO'), ('Greenville', 'NNP'), ('two', 'CD'), ('days', 'NNS'), ('before', 'IN'), ('annual', 'JJ'), ('testing', 'NN'), ('*-2', '-NONE-'), ('feeling', 'VBG'), ('that', 'IN'), ('she', 'PRP'), ('had', 'VBD'), ("n't", 'RB'), ('prepared', 'VBN'), ('her', 'PRP$'), ('low-ability', 'JJ'), ('geography', 'NN'), ('students', 'NNS'), ('adequately', 'RB'), ('.', '.')]
# 70  Mrs. Yeargin says that she also wanted to help lift Greenville High School 's overall test scores , usually near the bottom of 14 district high schools in rankings carried annually by local newspapers .
# ...
# 446  They know that whenever government is redistributing wealth , regulating commerce or maintaining a large defense establishment , there is big money to be made in influencing , brokering or selling the processes and decisions of government .
# [('They', 'PRP'), ('know', 'VBP'), ('that', 'IN'), ('whenever', 'WRB'), ('government', 'NN'), ('is', 'VBZ'), ('redistributing', 'VBG'), ('wealth', 'NN'), (',', ','), ('regulating', 'VBG'), ('commerce', 'NN'), ('or', 'CC'), ('maintaining', 'VBG'), ('a', 'DT'), ('large', 'JJ'), ('defense', 'NN'), ('establishment', 'NN'), ('*T*-2', '-NONE-'), (',', ','), ('there', 'EX'), ('is', 'VBZ'), ('big', 'JJ'), ('money', 'NN'), ('0', '-NONE-'), ('*T*-3', '-NONE-'), ('to', 'TO'), ('be', 'VB'), ('made', 'VBN'), ('*-1', '-NONE-'), ('in', 'IN'), ('*', '-NONE-'), ('influencing', 'VBG'), (',', ','), ('brokering', 'VBG'), ('or', 'CC'), ('selling', 'VBG'), ('the', 'DT'), ('processes', 'NNS'), ('and', 'CC'), ('decisions', 'NNS'), ('of', 'IN'), ('government', 'NN'), ('.', '.')]
# 447  `` The situation is that the bankruptcy court will get out of the shipbuilding business .
# [('``', '``'), ('The', 'DT'), ('situation', 'NN'), ('is', 'VBZ'), ('that', 'IN'), ('the', 'DT'), ('bankruptcy', 'NN'), ('court', 'NN'), ('will', 'MD'), ('get', 'VB'), ('out', 'IN'), ('of', 'IN'), ('the', 'DT'), ('shipbuilding', 'NN'), ('business', 'NN'), ('.', '.')]
# 448  The Soviet purchases are so massive that exporters are struggling to find enough river barges and trains to move the recently harvested Midwest crop to ports for loading onto Soviet ships .
# [('The', 'DT'), ('Soviet', 'JJ'), ('purchases', 'NNS'), ('are', 'VBP'), ('so', 'RB'), ('massive', 'JJ'), ('that', 'IN'), ('exporters', 'NNS'), ('are', 'VBP'), ('struggling', 'VBG'), ('*-1', '-NONE-'), ('to', 'TO'), ('find', 'VB'), ('enough', 'JJ'), ('river', 'NN'), ('barges', 'NNS'), ('and', 'CC'), ('trains', 'NNS'), ('0', '-NONE-'), ('*T*-2', '-NONE-'), ('to', 'TO'), ('move', 'VB'), ('the', 'DT'), ('recently', 'RB'), ('harvested', 'VBN'), ('Midwest', 'NN'), ('crop', 'NN'), ('to', 'TO'), ('ports', 'NNS'), ('for', 'IN'), ('*', '-NONE-'), ('loading', 'VBG'), ('onto', 'IN'), ('Soviet', 'JJ'), ('ships', 'NNS'), ('.', '.')]
# 449  And some grain analysts are predicting that corn prices might gyrate this month as exporters scrounge to find enough of the crop to meet their obligations to the Soviets .
# [('And', 'CC'), ('some', 'DT'), ('grain', 'NN'), ('analysts', 'NNS'), ('are', 'VBP'), ('predicting', 'VBG'), ('that', 'IN'), ('corn', 'NN'), ('prices', 'NNS'), ('might', 'MD'), ('gyrate', 'VB'), ('this', 'DT'), ('month', 'NN'), ('as', 'IN'), ('exporters', 'NNS'), ('scrounge', 'VBP'), ('*-1', '-NONE-'), ('to', 'TO'), ('find', 'VB'), ('enough', 'RB'), ('of', 'IN'), ('the', 'DT'), ('crop', 'NN'), ('0', '-NONE-'), ('*T*-2', '-NONE-'), ('to', 'TO'), ('meet', 'VB'), ('their', 'PRP$'), ('obligations', 'NNS'), ('to', 'TO'), ('the', 'DT'), ('Soviets', 'NNPS'), ('.', '.')]
# 450  Because of persistent dry weather in the northern Plains , the water level on the upper section of the Mississippi River is so low that many river operators are already trimming the number of barges their tows push at one time .
# [('Because', 'IN'), ('of', 'IN'), ('persistent', 'JJ'), ('dry', 'JJ'), ('weather', 'NN'), ('in', 'IN'), ('the', 'DT'), ('northern', 'JJ'), ('Plains', 'NNS'), (',', ','), ('the', 'DT'), ('water', 'NN'), ('level', 'NN'), ('on', 'IN'), ('the', 'DT'), ('upper', 'JJ'), ('section', 'NN'), ('of', 'IN'), ('the', 'DT'), ('Mississippi', 'NNP'), ('River', 'NNP'), ('is', 'VBZ'), ('so', 'RB'), ('low', 'JJ'), ('that', 'IN'), ('many', 'JJ'), ('river', 'NN'), ('operators', 'NNS'), ('are', 'VBP'), ('already', 'RB'), ('trimming', 'VBG'), ('the', 'DT'), ('number', 'NN'), ('of', 'IN'), ('barges', 'NNS'), ('0', '-NONE-'), ('their', 'PRP$'), ('tows', 'NNS'), ('push', 'VBP'), ('*T*-1', '-NONE-'), ('at', 'IN'), ('one', 'CD'), ('time', 'NN'), ('.', '.')]
# 451  Barge rates on the Mississippi River sank yesterday on speculation that widespread rain this week in the Midwest might temporarily alleviate the situation .
# [('Barge', 'NN'), ('rates', 'NNS'), ('on', 'IN'), ('the', 'DT'), ('Mississippi', 'NNP'), ('River', 'NNP'), ('sank', 'VBD'), ('yesterday', 'NN'), ('on', 'IN'), ('speculation', 'NN'), ('that', 'IN'), ('widespread', 'JJ'), ('rain', 'NN'), ('*ICH*-3', '-NONE-'), ('this', 'DT'), ('week', 'NN'), ('in', 'IN'), ('the', 'DT'), ('Midwest', 'NN'), ('might', 'MD'), ('temporarily', 'RB'), ('alleviate', 'VB'), ('the', 'DT'), ('situation', 'NN'), ('.', '.')]
# 452  With the harvest winding down , however , some analysts are speculating that prices might jump in some regions as U.S. exporters try to gather the corn they are obligated to deliver .
# [('With', 'IN'), ('the', 'DT'), ('harvest', 'NN'), ('winding', 'VBG'), ('down', 'IN'), (',', ','), ('however', 'RB'), (',', ','), ('some', 'DT'), ('analysts', 'NNS'), ('are', 'VBP'), ('speculating', 'VBG'), ('that', 'IN'), ('prices', 'NNS'), ('might', 'MD'), ('jump', 'VB'), ('in', 'IN'), ('some', 'DT'), ('regions', 'NNS'), ('as', 'IN'), ('U.S.', 'NNP'), ('exporters', 'NNS'), ('try', 'VBP'), ('*-1', '-NONE-'), ('to', 'TO'), ('gather', 'VB'), ('the', 'DT'), ('corn', 'NN'), ('0', '-NONE-'), ('they', 'PRP'), ('are', 'VBP'), ('obligated', 'VBN'), ('*-3', '-NONE-'), ('to', 'TO'), ('deliver', 'VB'), ('*T*-2', '-NONE-'), ('.', '.')]
# 453  Although U.S. corn stockpiles shrank by roughly half in the wake of the drought , the Agriculture Department projects that nearly one-fifth of the harvest will still be in storage before the 1990 corn harvest begins .
# [('Although', 'IN'), ('U.S.', 'NNP'), ('corn', 'NN'), ('stockpiles', 'NNS'), ('shrank', 'VBD'), ('by', 'IN'), ('roughly', 'RB'), ('half', 'DT'), ('in', 'IN'), ('the', 'DT'), ('wake', 'NN'), ('of', 'IN'), ('the', 'DT'), ('drought', 'NN'), (',', ','), ('the', 'DT'), ('Agriculture', 'NNP'), ('Department', 'NNP'), ('projects', 'VBZ'), ('that', 'IN'), ('nearly', 'RB'), ('one-fifth', 'NN'), ('of', 'IN'), ('the', 'DT'), ('harvest', 'NN'), ('will', 'MD'), ('still', 'RB'), ('be', 'VB'), ('in', 'IN'), ('storage', 'NN'), ('before', 'IN'), ('the', 'DT'), ('1990', 'CD'), ('corn', 'NN'), ('harvest', 'NN'), ('begins', 'VBZ'), ('.', '.')]
# 454  Some analysts are worried that reports of the grain industry 's problems might spark investors to begin buying corn futures contracts -- only to see little appreciation .
# [('Some', 'DT'), ('analysts', 'NNS'), ('are', 'VBP'), ('worried', 'VBN'), ('that', 'IN'), ('reports', 'NNS'), ('of', 'IN'), ('the', 'DT'), ('grain', 'NN'), ('industry', 'NN'), ("'s", 'POS'), ('problems', 'NNS'), ('might', 'MD'), ('spark', 'VB'), ('investors', 'NNS'), ('to', 'TO'), ('begin', 'VB'), ('*-1', '-NONE-'), ('buying', 'VBG'), ('corn', 'NN'), ('futures', 'NNS'), ('contracts', 'NNS'), ('--', ':'), ('*-2', '-NONE-'), ('only', 'RB'), ('to', 'TO'), ('see', 'VB'), ('little', 'JJ'), ('appreciation', 'NN'), ('.', '.')]
# 455  And it is n't clear that the Soviet Union will stay on its record buying pace .
# [('And', 'CC'), ('it', 'PRP'), ('*EXP*-2', '-NONE-'), ('is', 'VBZ'), ("n't", 'RB'), ('clear', 'JJ'), ('that', 'IN'), ('the', 'DT'), ('Soviet', 'NNP'), ('Union', 'NNP'), ('will', 'MD'), ('stay', 'VB'), ('on', 'IN'), ('its', 'PRP$'), ('record', 'NN'), ('buying', 'VBG'), ('pace', 'NN'), ('.', '.')]
# 456  Prices rose on the news that a sizable West German refinery was damaged in a fire , tightening an already tight European market .
# [('Prices', 'NNS'), ('rose', 'VBD'), ('on', 'IN'), ('the', 'DT'), ('news', 'NN'), ('that', 'IN'), ('a', 'DT'), ('sizable', 'JJ'), ('West', 'JJ'), ('German', 'JJ'), ('refinery', 'NN'), ('was', 'VBD'), ('damaged', 'VBN'), ('*-1', '-NONE-'), ('in', 'IN'), ('a', 'DT'), ('fire', 'NN'), (',', ','), ('*', '-NONE-'), ('tightening', 'VBG'), ('an', 'DT'), ('already', 'RB'), ('tight', 'JJ'), ('European', 'JJ'), ('market', 'NN'), ('.', '.')]
# 457  The analyst noted that also inherent in all metal markets was a sympathetic reaction to stocks .
# [('The', 'DT'), ('analyst', 'NN'), ('noted', 'VBD'), ('that', 'IN'), ('also', 'RB'), ('inherent', 'JJ'), ('in', 'IN'), ('all', 'DT'), ('metal', 'NN'), ('markets', 'NNS'), ('was', 'VBD'), ('*T*-1', '-NONE-'), ('a', 'DT'), ('sympathetic', 'JJ'), ('reaction', 'NN'), ('to', 'TO'), ('stocks', 'NNS'), ('.', '.')]
# 458  The Chicago report raised the possibility that the October survey of the National Association of Purchasing Management would also show a reading above 50 % .
# [('The', 'DT'), ('Chicago', 'NNP'), ('report', 'NN'), ('raised', 'VBD'), ('the', 'DT'), ('possibility', 'NN'), ('that', 'IN'), ('the', 'DT'), ('October', 'NNP'), ('survey', 'NN'), ('of', 'IN'), ('the', 'DT'), ('National', 'NNP'), ('Association', 'NNP'), ('of', 'IN'), ('Purchasing', 'NNP'), ('Management', 'NNP'), ('would', 'MD'), ('also', 'RB'), ('show', 'VB'), ('a', 'DT'), ('reading', 'NN'), ('above', 'IN'), ('50', 'CD'), ('%', 'NN'), ('.', '.')]
# 459  Peter Marcus , an analyst with PaineWebber Inc. , said that a downturn in the appliance industry , coupled with sluggish automotive sales , hurt USX results .
# [('Peter', 'NNP'), ('Marcus', 'NNP'), (',', ','), ('an', 'DT'), ('analyst', 'NN'), ('with', 'IN'), ('PaineWebber', 'NNP'), ('Inc.', 'NNP'), (',', ','), ('said', 'VBD'), ('that', 'IN'), ('a', 'DT'), ('downturn', 'NN'), ('in', 'IN'), ('the', 'DT'), ('appliance', 'NN'), ('industry', 'NN'), (',', ','), ('coupled', 'VBN'), ('*', '-NONE-'), ('with', 'IN'), ('sluggish', 'JJ'), ('automotive', 'JJ'), ('sales', 'NNS'), (',', ','), ('hurt', 'VBP'), ('USX', 'NNP'), ('results', 'NNS'), ('.', '.')]
# 460  The rise in the stock 's price may also reflect the fact that USX 's steel segment fared better than some other steelmakers ' .
# [('The', 'DT'), ('rise', 'NN'), ('in', 'IN'), ('the', 'DT'), ('stock', 'NN'), ("'s", 'POS'), ('price', 'NN'), ('may', 'MD'), ('also', 'RB'), ('reflect', 'VB'), ('the', 'DT'), ('fact', 'NN'), ('that', 'IN'), ('USX', 'NNP'), ("'s", 'POS'), ('steel', 'NN'), ('segment', 'NN'), ('fared', 'VBD'), ('better', 'RBR'), ('than', 'IN'), ('some', 'DT'), ('other', 'JJ'), ('steelmakers', 'NNS'), ("'", 'POS'), ('.', '.')]
# 461  USX announced in October that it was soliciting bids to sell TXO 's oil and gas reserves .
# [('USX', 'NNP'), ('announced', 'VBD'), ('in', 'IN'), ('October', 'NNP'), ('that', 'IN'), ('it', 'PRP'), ('was', 'VBD'), ('soliciting', 'VBG'), ('bids', 'NNS'), ('*', '-NONE-'), ('to', 'TO'), ('sell', 'VB'), ('TXO', 'NNP'), ("'s", 'POS'), ('oil', 'NN'), ('and', 'CC'), ('gas', 'NN'), ('reserves', 'NNS'), ('.', '.')]
# 462  The company noted that it has reduced debt by $ 1.6 billion since the end of 1988 and bought back about 15.5 million shares of common stock since the fourth quarter of 1987 .
# [('The', 'DT'), ('company', 'NN'), ('noted', 'VBD'), ('that', 'IN'), ('it', 'PRP'), ('has', 'VBZ'), ('reduced', 'VBN'), ('debt', 'NN'), ('by', 'IN'), ('$', '$'), ('1.6', 'CD'), ('billion', 'CD'), ('*U*', '-NONE-'), ('since', 'IN'), ('the', 'DT'), ('end', 'NN'), ('of', 'IN'), ('1988', 'CD'), ('and', 'CC'), ('bought', 'VBD'), ('back', 'RP'), ('about', 'IN'), ('15.5', 'CD'), ('million', 'CD'), ('shares', 'NNS'), ('of', 'IN'), ('common', 'JJ'), ('stock', 'NN'), ('since', 'IN'), ('the', 'DT'), ('fourth', 'JJ'), ('quarter', 'NN'), ('of', 'IN'), ('1987', 'CD'), ('.', '.')]
# 463  The announced sale of the reserves was followed by news that investor Carl Icahn had increased his stake in USX to 13.1 % and threatened a takeover or other business combination .
# [('The', 'DT'), ('announced', 'VBN'), ('sale', 'NN'), ('of', 'IN'), ('the', 'DT'), ('reserves', 'NNS'), ('was', 'VBD'), ('followed', 'VBN'), ('*-1', '-NONE-'), ('by', 'IN'), ('news', 'NN'), ('that', 'IN'), ('investor', 'NN'), ('Carl', 'NNP'), ('Icahn', 'NNP'), ('had', 'VBD'), ('increased', 'VBN'), ('his', 'PRP$'), ('stake', 'NN'), ('in', 'IN'), ('USX', 'NNP'), ('to', 'TO'), ('13.1', 'CD'), ('%', 'NN'), ('and', 'CC'), ('threatened', 'VBN'), ('a', 'DT'), ('takeover', 'NN'), ('or', 'CC'), ('other', 'JJ'), ('business', 'NN'), ('combination', 'NN'), ('.', '.')]
# 464  A White House spokesman said last week that the president is considering declaring that the Constitution implicitly gives him the authority for a line-item veto to provoke a test case .
# [('A', 'DT'), ('White', 'NNP'), ('House', 'NNP'), ('spokesman', 'NN'), ('said', 'VBD'), ('last', 'JJ'), ('week', 'NN'), ('that', 'IN'), ('the', 'DT'), ('president', 'NN'), ('is', 'VBZ'), ('considering', 'VBG'), ('*-1', '-NONE-'), ('declaring', 'VBG'), ('that', 'IN'), ('the', 'DT'), ('Constitution', 'NNP'), ('implicitly', 'RB'), ('gives', 'VBZ'), ('him', 'PRP'), ('the', 'DT'), ('authority', 'NN'), ('for', 'IN'), ('a', 'DT'), ('line-item', 'JJ'), ('veto', 'NN'), ('*-2', '-NONE-'), ('to', 'TO'), ('provoke', 'VB'), ('a', 'DT'), ('test', 'NN'), ('case', 'NN'), ('.', '.')]
# 465  But the two legal experts , responding to an inquiry by Sen. Edward Kennedy -LRB- D. , Mass. -RRB- , wrote in a joint letter that the president `` lacks the constitutional authority to exercise a line-item veto . ''
# [('But', 'CC'), ('the', 'DT'), ('two', 'CD'), ('legal', 'JJ'), ('experts', 'NNS'), (',', ','), ('responding', 'VBG'), ('to', 'TO'), ('an', 'DT'), ('inquiry', 'NN'), ('by', 'IN'), ('Sen.', 'NNP'), ('Edward', 'NNP'), ('Kennedy', 'NNP'), ('-LRB-', '-LRB-'), ('D.', 'NNP'), (',', ','), ('Mass.', 'NNP'), ('-RRB-', '-RRB-'), (',', ','), ('wrote', 'VBD'), ('in', 'IN'), ('a', 'DT'), ('joint', 'JJ'), ('letter', 'NN'), ('that', 'IN'), ('the', 'DT'), ('president', 'NN'), ('``', '``'), ('lacks', 'VBZ'), ('the', 'DT'), ('constitutional', 'JJ'), ('authority', 'NN'), ('*', '-NONE-'), ('to', 'TO'), ('exercise', 'VB'), ('a', 'DT'), ('line-item', 'JJ'), ('veto', 'NN'), ('.', '.'), ("''", "''")]
# 466  They also said that more than a dozen presidents have called for line-item veto authority since the Civil War , and `` all have shared the view that such lawmaking power is beyond the reach '' of the president .
# [('They', 'PRP'), ('also', 'RB'), ('said', 'VBD'), ('that', 'IN'), ('more', 'JJR'), ('than', 'IN'), ('a', 'DT'), ('dozen', 'NN'), ('presidents', 'NNS'), ('*PPA*-1', '-NONE-'), ('have', 'VBP'), ('called', 'VBN'), ('for', 'IN'), ('line-item', 'JJ'), ('veto', 'NN'), ('authority', 'NN'), ('since', 'IN'), ('the', 'DT'), ('Civil', 'NNP'), ('War', 'NNP'), (',', ','), ('and', 'CC'), ('``', '``'), ('all', 'DT'), ('have', 'VBP'), ('shared', 'VBN'), ('the', 'DT'), ('view', 'NN'), ('that', 'IN'), ('such', 'JJ'), ('lawmaking', 'JJ'), ('power', 'NN'), ('is', 'VBZ'), ('beyond', 'IN'), ('the', 'DT'), ('reach', 'NN'), ("''", "''"), ('of', 'IN'), ('the', 'DT'), ('president', 'NN'), ('.', '.')]
# 467  Sen. Kennedy said in a separate statement that he supports legislation to give the president line-item veto power , but that it would be a `` reckless course of action '' for President Bush to claim the authority without congressional approval .
# [('Sen.', 'NNP'), ('Kennedy', 'NNP'), ('said', 'VBD'), ('in', 'IN'), ('a', 'DT'), ('separate', 'JJ'), ('statement', 'NN'), ('that', 'IN'), ('he', 'PRP'), ('supports', 'VBZ'), ('legislation', 'NN'), ('0', '-NONE-'), ('*', '-NONE-'), ('to', 'TO'), ('give', 'VB'), ('the', 'DT'), ('president', 'NN'), ('line-item', 'JJ'), ('veto', 'NN'), ('power', 'NN'), ('*T*-2', '-NONE-'), (',', ','), ('but', 'CC'), ('that', 'IN'), ('it', 'PRP'), ('*EXP*-1', '-NONE-'), ('would', 'MD'), ('be', 'VB'), ('a', 'DT'), ('``', '``'), ('reckless', 'JJ'), ('course', 'NN'), ('of', 'IN'), ('action', 'NN'), ("''", "''"), ('for', 'IN'), ('President', 'NNP'), ('Bush', 'NNP'), ('to', 'TO'), ('claim', 'VB'), ('the', 'DT'), ('authority', 'NN'), ('without', 'IN'), ('congressional', 'JJ'), ('approval', 'NN'), ('.', '.')]

# %%
get_ground_truth_examples(token='that', corpus=treebank, tag='ADV', universal_tagset=True)
# Out:
# 1  While *-1 acknowledging 0 one month 's figures do n't prove a trend , Mr. Bretz said , `` It does lead you to suspect 0 imports are going down , or at least not increasing that much . ''
# [('While', 'ADP'), ('*-1', 'X'), ('acknowledging', 'VERB'), ('0', 'X'), ('one', 'NUM'), ('month', 'NOUN'), ("'s", 'PRT'), ('figures', 'NOUN'), ('do', 'VERB'), ("n't", 'ADV'), ('prove', 'VERB'), ('a', 'DET'), ('trend', 'NOUN'), (',', '.'), ('Mr.', 'NOUN'), ('Bretz', 'NOUN'), ('said', 'VERB'), (',', '.'), ('``', '.'), ('It', 'PRON'), ('does', 'VERB'), ('lead', 'VERB'), ('you', 'PRON'), ('to', 'PRT'), ('suspect', 'VERB'), ('0', 'X'), ('imports', 'NOUN'), ('are', 'VERB'), ('going', 'VERB'), ('down', 'ADV'), (',', '.'), ('or', 'CONJ'), ('at', 'ADP'), ('least', 'ADJ'), ('not', 'ADV'), ('increasing', 'VERB'), ('that', 'ADV'), ('much', 'ADV'), ('.', '.'), ("''", '.')]
# 2  * Winning a bonus for a third year was n't that important to her , Mrs. Yeargin insists 0 *T*-1 .
# [('*', 'X'), ('Winning', 'VERB'), ('a', 'DET'), ('bonus', 'NOUN'), ('for', 'ADP'), ('a', 'DET'), ('third', 'ADJ'), ('year', 'NOUN'), ('was', 'VERB'), ("n't", 'ADV'), ('that', 'ADV'), ('important', 'ADJ'), ('to', 'PRT'), ('her', 'PRON'), (',', '.'), ('Mrs.', 'NOUN'), ('Yeargin', 'NOUN'), ('insists', 'VERB'), ('0', 'X'), ('*T*-1', 'X'), ('.', '.')]
# 3  `` It *EXP*-1 's not easy * to roll out something that comprehensive , and make it pay , '' Mr. Jacob says *T*-2 .
# [('``', '.'), ('It', 'PRON'), ('*EXP*-1', 'X'), ("'s", 'VERB'), ('not', 'ADV'), ('easy', 'ADJ'), ('*', 'X'), ('to', 'PRT'), ('roll', 'VERB'), ('out', 'PRT'), ('something', 'NOUN'), ('that', 'ADV'), ('comprehensive', 'ADJ'), (',', '.'), ('and', 'CONJ'), ('make', 'VERB'), ('it', 'PRON'), ('pay', 'VERB'), (',', '.'), ("''", '.'), ('Mr.', 'NOUN'), ('Jacob', 'NOUN'), ('says', 'VERB'), ('*T*-2', 'X'), ('.', '.')]
